# %%
#Import dependencies

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Create a set of random latitude and longitude combinations.

lats = np.random.uniform(low=-90.000,high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000,high=180.000, size=2000)

lat_lngs = zip(lats,lngs)

lat_lngs

# %%
#Add the latitudes and longitudes to a list.

coordinates = list(lat_lngs)
coordinates
# Out:
# [(2.6648762331645486, -38.11151857809199),
#  (65.48069430474763, 103.23370791035273),
#  (-37.49520418884492, -91.40190673764144),
#  (-37.01274542465719, 34.056027114474915),
#  (-7.473996728248167, -178.65573298879096),
#  (72.64220855815213, 71.0524601335135),
#  (-71.8981495305949, 30.432002525714523),
#  (-1.1825227464293278, 62.35481394541114),
#  (-54.86353020890743, -42.53079770571216),
#  (25.423919077372574, -86.57030640419713),
#  (-2.728989821425216, -124.67978005223817),
#  (76.80815015788085, 35.52348469860533),
#  (36.86139383934908, 168.4863410240772),
#  (17.540570681709056, -91.94872353620556),
#  (63.41268277418288, 127.4842637920637),
#  (45.55262658831646, -169.29266887822948),
#  (-9.635515667497671, -4.412422732902797),
#  (33.31894978861003, 42.22561262919646),
#  (-35.318323555449616, 165.2360864586127),
#  (-4.591743685041507, 157.26168562832186),
#  (78.97158825382016, 170.18311225463748),
#  (-35.61676615091075, -2.2924827957558875),
# ...

# %%
from citipy import citipy

#Create a list for holding the cities.

cities = []

#Identify the nearest city for each latitude and longitude combination. 

for coordinate in coordinates: 
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list. 
    
    if city not in cities:
        cities.append(city)
        
#Print the city count to confirm sufficient count.

len(cities)
# Out:
# 742

# %%
cities
# Out:
# ['itarema',
#  'tura',
#  'lebu',
#  'umzimvubu',
#  'vaitupu',
#  'yar-sale',
#  'port elizabeth',
#  'victoria',
#  'mar del plata',
#  'mantua',
#  'atuona',
#  'vardo',
#  'nikolskoye',
#  'palenque',
#  'sangar',
#  'bethel',
#  'jamestown',
#  'hit',
#  'ahipara',
#  'kieta',
#  'pevek',
#  'luderitz',
#  'lorengau',
#  'upernavik',
#  'ushuaia',
#  'bourail',
#  'avarua',
#  'busselton',
#  'mount gambier',
#  'meulaboh',
#  'mataura',
#  'bambous virieux',
#  'doctor pedro p. pena',
#  'walvis bay',
#  'rikitea',
#  'carutapera',
#  'kapaa',
#  'esperance',
#  'shelburne',
#  'siguiri',
#  'tilichiki',
#  'balimo',
#  'la asuncion',
#  'nanortalik',
#  'mahebourg',
#  'chernyshevskiy',
#  'saint george',
#  'caconda',
#  'punta arenas',
#  'new norfolk',
#  'castro',
#  'norman wells',
#  'fergus falls',
#  'kerki',
#  'vila velha',
#  'karratha',
#  'puerto ayora',
#  'bluff',
#  'ayr',
#  'morsbach',
#  'baiyin',
#  'qaanaaq',
#  'port hedland',
#  'vaini',
#  'dikson',
# ...

# %%
#Import Requests Library and the westher_api_key

import requests
from config2 import weather_api_key

#Import the time library and the datetime module from the datetime library

import time
from datetime import datetime

# %%
#Create an empty list to hold the weather data. 

city_data_new = []

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

#Print the beginning of the logging.

print("Beginning Data Retrieval       ")
print("-------------------------------")


#Create counters.

record_count = 1
set_count = 1

#Loop through all the cities in the list.

for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for logging purposes.
    if (i % 50 ==0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    #Create endpoint URL with each city.
    city_url_new = url + "&q=" + city.replace(" ","+")
    
    #Log the URL, record, and set numbers and the city. 
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    #Add 1 to the record count. 
    
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url_new).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data_new.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": weather})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
#         pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 1 | itarema
# Processing Record 2 of Set 1 | tura
# Processing Record 3 of Set 1 | lebu
# Processing Record 4 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 1 | yar-sale
# Processing Record 7 of Set 1 | port elizabeth
# Processing Record 8 of Set 1 | victoria
# Processing Record 9 of Set 1 | mar del plata
# Processing Record 10 of Set 1 | mantua
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | vardo
# Processing Record 13 of Set 1 | nikolskoye
# Processing Record 14 of Set 1 | palenque
# Processing Record 15 of Set 1 | sangar
# Processing Record 16 of Set 1 | bethel
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | hit
# Processing Record 19 of Set 1 | ahipara
# Processing Record 20 of Set 1 | kieta
# Processing Record 21 of Set 1 | pevek
# ...

# %%
city_data_new_df = pd.DataFrame(city_data_new)

city_data_new_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Itarema  -2.9248  -39.9167     77.56        83          19
# 1            Tura  25.5198   90.2201     81.43        83          97
# 2            Lebu -37.6167  -73.6500     42.69        79           1
# 3        Yar-Sale  66.8333   70.8333     46.36        86         100
# 4  Port Elizabeth -33.9180   25.5701     55.69        82           0
# 5        Victoria  22.2855  114.1577     92.25        76          53
# 6   Mar Del Plata -38.0023  -57.5575     57.09        96         100
# 7          Mantua  45.1667   10.7833     58.15        83          14
# 8          Atuona  -9.8000 -139.0333     76.84        75          16
# 9           Vardo  70.3705   31.1107     46.38        93          75
#
#    Wind Speed Country      Current Description
# 0       13.73      BR               few clouds
# 1        4.83      IN          overcast clouds
# 2        5.53      CL                clear sky
# ...

# %%
new_column_orders = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_new_df = city_data_new_df[new_column_orders]
city_data_new_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Itarema      BR  -2.9248  -39.9167     77.56        83          19
# 1            Tura      IN  25.5198   90.2201     81.43        83          97
# 2            Lebu      CL -37.6167  -73.6500     42.69        79           1
# 3        Yar-Sale      RU  66.8333   70.8333     46.36        86         100
# 4  Port Elizabeth      ZA -33.9180   25.5701     55.69        82           0
# 5        Victoria      HK  22.2855  114.1577     92.25        76          53
# 6   Mar Del Plata      AR -38.0023  -57.5575     57.09        96         100
# 7          Mantua      IT  45.1667   10.7833     58.15        83          14
# 8          Atuona      PF  -9.8000 -139.0333     76.84        75          16
# 9           Vardo      NO  70.3705   31.1107     46.38        93          75
#
#    Wind Speed      Current Description
# 0       13.73               few clouds
# 1        4.83          overcast clouds
# ...
