# %%
#Import dependencies

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Create a set of random latitude and longitude combinations.

lats = np.random.uniform(low=-90.000,high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000,high=180.000, size=1500)

lat_lngs = zip(lats,lngs)

lat_lngs

# %%
# # Create a practice set of random latitude and longitude combinations.
# lats = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
# lngs = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
# lat_lngs = zip(lats, lngs)

# %%
#Add the latitudes and longitudes to a list.

coordinates = list(lat_lngs)

# %%
#Use the print() function to display the latitude and longitude combinations. 

# for coordinate in coordinates:
#     print(coordinate[0], coordinate[1])

# %%
from citipy import citipy

#Create a list for holding the cities.

cities = []

#Identify the nearest city for each latitude and longitude combination. 

for coordinate in coordinates: 
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list. 
    
    if city not in cities:
        cities.append(city)
        
#Print the city count to confirm sufficient count.

len(cities)
# Out:
# 611

# %%
#Import Requests Library and the westher_api_key

import requests
from config import weather_api_key

#Import the time library and the datetime module from the datetime library

import time
from datetime import datetime

# %%
#Create an empty list to hold the weather data. 

city_data = []

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

#Print the beginning of the logging.

print("Beginning Data Retrieval       ")
print("-------------------------------")


#Create counters.

record_count = 1
set_count = 1

#Loop through all the cities in the list.

for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for logging purposes.
    if (i % 50 ==0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    #Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    #Log the URL, record, and set numbers and the city. 
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    #Add 1 to the record count. 
    
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 1 | katsuura
# Processing Record 2 of Set 1 | san quintin
# Processing Record 3 of Set 1 | akcaabat
# Processing Record 4 of Set 1 | constitucion
# Processing Record 5 of Set 1 | salalah
# Processing Record 6 of Set 1 | provideniya
# Processing Record 7 of Set 1 | tuktoyaktuk
# Processing Record 8 of Set 1 | erenhot
# Processing Record 9 of Set 1 | black diamond
# Processing Record 10 of Set 1 | alofi
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | saint-philippe
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | coihaique
# Processing Record 16 of Set 1 | launceston
# Processing Record 17 of Set 1 | hilo
# Processing Record 18 of Set 1 | vanavara
# Processing Record 19 of Set 1 | fortuna
# Processing Record 20 of Set 1 | hualmay
# Processing Record 21 of Set 1 | gat
# Processing Record 22 of Set 1 | torbay
# Processing Record 23 of Set 1 | buraydah
# Processing Record 24 of Set 1 | mahebourg
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | leh
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | taltal
# Processing Record 29 of Set 1 | dikson
# Processing Record 30 of Set 1 | vardo
# Processing Record 31 of Set 1 | port elizabeth
# Processing Record 32 of Set 1 | ribeira grande
# Processing Record 33 of Set 1 | narsaq
# Processing Record 34 of Set 1 | kavieng
# Processing Record 35 of Set 1 | hobart
# Processing Record 36 of Set 1 | albany
# Processing Record 37 of Set 1 | vila velha
# Processing Record 38 of Set 1 | mataura
# Processing Record 39 of Set 1 | arman
# Processing Record 40 of Set 1 | yulara
# Processing Record 41 of Set 1 | qaanaaq
# Processing Record 42 of Set 1 | bluff
# Processing Record 43 of Set 1 | kiunga
# Processing Record 44 of Set 1 | lebu
# Processing Record 45 of Set 1 | ndele
# Processing Record 46 of Set 1 | fort nelson
# Processing Record 47 of Set 1 | shakawe
# Processing Record 48 of Set 1 | chuy
# Processing Record 49 of Set 1 | alice springs
# Processing Record 50 of Set 1 | takoradi
# Processing Record 1 of Set 2 | nikolskoye
# Processing Record 2 of Set 2 | green river
# Processing Record 3 of Set 2 | brigantine
# Processing Record 4 of Set 2 | kamina
# Processing Record 5 of Set 2 | nome
# Processing Record 6 of Set 2 | vaini
# Processing Record 7 of Set 2 | seoul
# Processing Record 8 of Set 2 | tasiilaq
# Processing Record 9 of Set 2 | clyde river
# Processing Record 10 of Set 2 | bo phloi
# Processing Record 11 of Set 2 | andros town
# Processing Record 12 of Set 2 | vulcanesti
# Processing Record 13 of Set 2 | port shepstone
# Processing Record 14 of Set 2 | adrar
# Processing Record 15 of Set 2 | camacupa
# Processing Record 16 of Set 2 | gombong
# Processing Record 17 of Set 2 | nouakchott
# Processing Record 18 of Set 2 | olinda
# Processing Record 19 of Set 2 | punta arenas
# Processing Record 20 of Set 2 | carnarvon
# Processing Record 21 of Set 2 | kapaa
# Processing Record 22 of Set 2 | dalbandin
# Processing Record 23 of Set 2 | veracruz
# Processing Record 24 of Set 2 | chokurdakh
# Processing Record 25 of Set 2 | medford
# Processing Record 26 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 2 | jamestown
# Processing Record 28 of Set 2 | port alfred
# Processing Record 29 of Set 2 | kochevo
# Processing Record 30 of Set 2 | saldanha
# Processing Record 31 of Set 2 | ponta do sol
# Processing Record 32 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 33 of Set 2 | ancud
# Processing Record 34 of Set 2 | lata
# Processing Record 35 of Set 2 | atuona
# Processing Record 36 of Set 2 | skelleftea
# Processing Record 37 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 2 | gushikawa
# Processing Record 39 of Set 2 | esperance
# Processing Record 40 of Set 2 | mount isa
# Processing Record 41 of Set 2 | taburi
# City not found. Skipping...
# Processing Record 42 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 2 | quelimane
# Processing Record 44 of Set 2 | saint-pierre
# Processing Record 45 of Set 2 | codrington
# Processing Record 46 of Set 2 | saskylakh
# Processing Record 47 of Set 2 | vostok
# Processing Record 48 of Set 2 | upernavik
# Processing Record 49 of Set 2 | dalby
# Processing Record 50 of Set 2 | khatanga
# Processing Record 1 of Set 3 | buin
# Processing Record 2 of Set 3 | makakilo city
# Processing Record 3 of Set 3 | nabire
# Processing Record 4 of Set 3 | vila franca do campo
# Processing Record 5 of Set 3 | hermanus
# Processing Record 6 of Set 3 | rikitea
# Processing Record 7 of Set 3 | qasigiannguit
# Processing Record 8 of Set 3 | mundo nuevo
# Processing Record 9 of Set 3 | port hardy
# Processing Record 10 of Set 3 | mar del plata
# Processing Record 11 of Set 3 | victor harbor
# Processing Record 12 of Set 3 | perafita
# Processing Record 13 of Set 3 | thompson
# Processing Record 14 of Set 3 | geraldton
# Processing Record 15 of Set 3 | sant julia de loria
# Processing Record 16 of Set 3 | tlaltenango
# Processing Record 17 of Set 3 | barrow
# Processing Record 18 of Set 3 | korla
# Processing Record 19 of Set 3 | mahon
# Processing Record 20 of Set 3 | tromso
# Processing Record 21 of Set 3 | dwarka
# Processing Record 22 of Set 3 | la plata
# Processing Record 23 of Set 3 | nianzishan
# Processing Record 24 of Set 3 | college
# Processing Record 25 of Set 3 | bac lieu
# Processing Record 26 of Set 3 | hithadhoo
# Processing Record 27 of Set 3 | bengkulu
# Processing Record 28 of Set 3 | havre-saint-pierre
# Processing Record 29 of Set 3 | zharkent
# Processing Record 30 of Set 3 | ambilobe
# Processing Record 31 of Set 3 | birobidzhan
# Processing Record 32 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 3 | bredasdorp
# Processing Record 35 of Set 3 | yellowknife
# Processing Record 36 of Set 3 | bandarbeyla
# Processing Record 37 of Set 3 | buchanan
# Processing Record 38 of Set 3 | castres
# Processing Record 39 of Set 3 | dumaguil
# Processing Record 40 of Set 3 | kodiak
# Processing Record 41 of Set 3 | arequipa
# Processing Record 42 of Set 3 | touros
# Processing Record 43 of Set 3 | avarua
# Processing Record 44 of Set 3 | foumban
# Processing Record 45 of Set 3 | yian
# City not found. Skipping...
# Processing Record 46 of Set 3 | qarchi gak
# Processing Record 47 of Set 3 | puruaran
# Processing Record 48 of Set 3 | mackay
# Processing Record 49 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 3 | harper
# Processing Record 1 of Set 4 | marzuq
# Processing Record 2 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 4 | del rio
# Processing Record 4 of Set 4 | aasiaat
# Processing Record 5 of Set 4 | bowling green
# Processing Record 6 of Set 4 | qeshm
# Processing Record 7 of Set 4 | lompoc
# Processing Record 8 of Set 4 | kamenka
# Processing Record 9 of Set 4 | camocim
# Processing Record 10 of Set 4 | lisakovsk
# Processing Record 11 of Set 4 | los llanos de aridane
# Processing Record 12 of Set 4 | manzhouli
# Processing Record 13 of Set 4 | butaritari
# Processing Record 14 of Set 4 | samarai
# Processing Record 15 of Set 4 | sao joao da barra
# Processing Record 16 of Set 4 | tamandare
# Processing Record 17 of Set 4 | bonavista
# Processing Record 18 of Set 4 | bambous virieux
# Processing Record 19 of Set 4 | beringovskiy
# Processing Record 20 of Set 4 | lake charles
# Processing Record 21 of Set 4 | kruisfontein
# Processing Record 22 of Set 4 | flinders
# Processing Record 23 of Set 4 | bichena
# Processing Record 24 of Set 4 | east london
# Processing Record 25 of Set 4 | chalmette
# Processing Record 26 of Set 4 | castro
# Processing Record 27 of Set 4 | puerto del rosario
# Processing Record 28 of Set 4 | okha
# Processing Record 29 of Set 4 | dakar
# Processing Record 30 of Set 4 | sitka
# Processing Record 31 of Set 4 | campana
# Processing Record 32 of Set 4 | altagracia de orituco
# Processing Record 33 of Set 4 | cayenne
# Processing Record 34 of Set 4 | berlevag
# Processing Record 35 of Set 4 | tuatapere
# Processing Record 36 of Set 4 | erzin
# Processing Record 37 of Set 4 | florence
# Processing Record 38 of Set 4 | biak
# Processing Record 39 of Set 4 | taloda
# Processing Record 40 of Set 4 | cherskiy
# Processing Record 41 of Set 4 | sibolga
# Processing Record 42 of Set 4 | langsa
# Processing Record 43 of Set 4 | hun
# Processing Record 44 of Set 4 | komsomolskiy
# Processing Record 45 of Set 4 | husavik
# Processing Record 46 of Set 4 | sigli
# Processing Record 47 of Set 4 | vestmanna
# Processing Record 48 of Set 4 | camacha
# Processing Record 49 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 4 | saint george
# Processing Record 1 of Set 5 | bethel
# Processing Record 2 of Set 5 | andrushivka
# Processing Record 3 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 5 | norman wells
# Processing Record 5 of Set 5 | pisco
# Processing Record 6 of Set 5 | gizo
# Processing Record 7 of Set 5 | asau
# Processing Record 8 of Set 5 | ponta delgada
# Processing Record 9 of Set 5 | changji
# Processing Record 10 of Set 5 | san jose
# Processing Record 11 of Set 5 | souillac
# Processing Record 12 of Set 5 | kharp
# Processing Record 13 of Set 5 | baiyin
# Processing Record 14 of Set 5 | tual
# Processing Record 15 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 5 | oranjemund
# Processing Record 17 of Set 5 | hervey bay
# Processing Record 18 of Set 5 | pali
# Processing Record 19 of Set 5 | rawah
# Processing Record 20 of Set 5 | qiqihar
# Processing Record 21 of Set 5 | caravelas
# Processing Record 22 of Set 5 | magistralnyy
# Processing Record 23 of Set 5 | kuching
# Processing Record 24 of Set 5 | mehamn
# Processing Record 25 of Set 5 | kaitangata
# Processing Record 26 of Set 5 | jumla
# Processing Record 27 of Set 5 | iqaluit
# Processing Record 28 of Set 5 | satipo
# Processing Record 29 of Set 5 | general roca
# Processing Record 30 of Set 5 | lidkoping
# Processing Record 31 of Set 5 | yerofey pavlovich
# Processing Record 32 of Set 5 | isla aguada
# Processing Record 33 of Set 5 | ipora
# Processing Record 34 of Set 5 | tessalit
# Processing Record 35 of Set 5 | northam
# Processing Record 36 of Set 5 | luanda
# Processing Record 37 of Set 5 | barmer
# Processing Record 38 of Set 5 | arraial do cabo
# Processing Record 39 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 5 | sept-iles
# Processing Record 41 of Set 5 | praia da vitoria
# Processing Record 42 of Set 5 | solnechnyy
# Processing Record 43 of Set 5 | risod
# Processing Record 44 of Set 5 | imbituba
# Processing Record 45 of Set 5 | nishihara
# Processing Record 46 of Set 5 | sao filipe
# Processing Record 47 of Set 5 | slonim
# Processing Record 48 of Set 5 | saint-augustin
# Processing Record 49 of Set 5 | stolin
# Processing Record 50 of Set 5 | bonthe
# Processing Record 1 of Set 6 | bitung
# Processing Record 2 of Set 6 | pasighat
# Processing Record 3 of Set 6 | bam
# Processing Record 4 of Set 6 | bekwai
# Processing Record 5 of Set 6 | caruaru
# Processing Record 6 of Set 6 | ilulissat
# Processing Record 7 of Set 6 | yonago
# Processing Record 8 of Set 6 | katherine
# Processing Record 9 of Set 6 | khonsa
# Processing Record 10 of Set 6 | tucuman
# Processing Record 11 of Set 6 | ishinomaki
# Processing Record 12 of Set 6 | sorland
# Processing Record 13 of Set 6 | henties bay
# Processing Record 14 of Set 6 | roald
# Processing Record 15 of Set 6 | corner brook
# Processing Record 16 of Set 6 | skjervoy
# Processing Record 17 of Set 6 | itatskiy
# Processing Record 18 of Set 6 | guarapari
# Processing Record 19 of Set 6 | sao miguel do araguaia
# Processing Record 20 of Set 6 | daru
# Processing Record 21 of Set 6 | paveh
# Processing Record 22 of Set 6 | tiksi
# Processing Record 23 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 24 of Set 6 | lagoa
# Processing Record 25 of Set 6 | georgetown
# Processing Record 26 of Set 6 | severo-kurilsk
# Processing Record 27 of Set 6 | zhangye
# City not found. Skipping...
# Processing Record 28 of Set 6 | port-gentil
# City not found. Skipping...
# Processing Record 29 of Set 6 | gawler
# City not found. Skipping...
# Processing Record 30 of Set 6 | hvammstangi
# City not found. Skipping...
# Processing Record 31 of Set 6 | hay river
# Processing Record 32 of Set 6 | prince rupert
# Processing Record 33 of Set 6 | san cristobal
# Processing Record 34 of Set 6 | ixtapa
# Processing Record 35 of Set 6 | huanren
# Processing Record 36 of Set 6 | nanortalik
# Processing Record 37 of Set 6 | kitami
# Processing Record 38 of Set 6 | sobolevo
# Processing Record 39 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 6 | batagay-alyta
# Processing Record 41 of Set 6 | tanete
# Processing Record 42 of Set 6 | dumai
# Processing Record 43 of Set 6 | palmer
# Processing Record 44 of Set 6 | lluta
# Processing Record 45 of Set 6 | hami
# Processing Record 46 of Set 6 | bathsheba
# Processing Record 47 of Set 6 | vao
# Processing Record 48 of Set 6 | wucheng
# Processing Record 49 of Set 6 | dunedin
# Processing Record 50 of Set 6 | koslan
# Processing Record 1 of Set 7 | orange
# Processing Record 2 of Set 7 | haines junction
# Processing Record 3 of Set 7 | rio gallegos
# Processing Record 4 of Set 7 | saint-paul
# Processing Record 5 of Set 7 | rabo de peixe
# Processing Record 6 of Set 7 | yar-sale
# Processing Record 7 of Set 7 | balsas
# Processing Record 8 of Set 7 | lida
# Processing Record 9 of Set 7 | xixiang
# Processing Record 10 of Set 7 | meulaboh
# Processing Record 11 of Set 7 | leningradskiy
# Processing Record 12 of Set 7 | victoria
# Processing Record 13 of Set 7 | waipawa
# Processing Record 14 of Set 7 | lavrentiya
# Processing Record 15 of Set 7 | yaan
# Processing Record 16 of Set 7 | bambanglipuro
# Processing Record 17 of Set 7 | scottsburgh
# City not found. Skipping...
# Processing Record 18 of Set 7 | bubaque
# Processing Record 19 of Set 7 | pevek
# Processing Record 20 of Set 7 | manturovo
# Processing Record 21 of Set 7 | dombarovskiy
# Processing Record 22 of Set 7 | iberia
# Processing Record 23 of Set 7 | talnakh
# Processing Record 24 of Set 7 | anshun
# Processing Record 25 of Set 7 | saint-georges
# Processing Record 26 of Set 7 | gao
# Processing Record 27 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 28 of Set 7 | guerrero negro
# Processing Record 29 of Set 7 | orlik
# Processing Record 30 of Set 7 | lesnoy
# Processing Record 31 of Set 7 | airai
# Processing Record 32 of Set 7 | saint-joseph
# Processing Record 33 of Set 7 | mackenzie
# Processing Record 34 of Set 7 | temiscaming
# Processing Record 35 of Set 7 | la union
# Processing Record 36 of Set 7 | olafsvik
# Processing Record 37 of Set 7 | kassala
# Processing Record 38 of Set 7 | garowe
# Processing Record 39 of Set 7 | perehonivka
# Processing Record 40 of Set 7 | dayong
# Processing Record 41 of Set 7 | kremenchuk
# Processing Record 42 of Set 7 | santo domingo
# Processing Record 43 of Set 7 | mount gambier
# Processing Record 44 of Set 7 | khor
# Processing Record 45 of Set 7 | oxapampa
# Processing Record 46 of Set 7 | high level
# Processing Record 47 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 48 of Set 7 | mildura
# Processing Record 49 of Set 7 | manokwari
# Processing Record 50 of Set 7 | karauzyak
# City not found. Skipping...
# Processing Record 1 of Set 8 | sukhodol
# Processing Record 2 of Set 8 | culpeper
# Processing Record 3 of Set 8 | namibe
# Processing Record 4 of Set 8 | canico
# Processing Record 5 of Set 8 | aguadilla
# Processing Record 6 of Set 8 | ostrovnoy
# Processing Record 7 of Set 8 | cidreira
# Processing Record 8 of Set 8 | chapais
# Processing Record 9 of Set 8 | sioux lookout
# Processing Record 10 of Set 8 | cairns
# Processing Record 11 of Set 8 | manicore
# Processing Record 12 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 8 | wolgast
# Processing Record 14 of Set 8 | mutis
# Processing Record 15 of Set 8 | harrison
# Processing Record 16 of Set 8 | praia
# Processing Record 17 of Set 8 | kautokeino
# Processing Record 18 of Set 8 | shimoda
# Processing Record 19 of Set 8 | klobuck
# Processing Record 20 of Set 8 | taree
# Processing Record 21 of Set 8 | taveta
# Processing Record 22 of Set 8 | teguldet
# Processing Record 23 of Set 8 | havoysund
# Processing Record 24 of Set 8 | shillong
# Processing Record 25 of Set 8 | mlonggo
# Processing Record 26 of Set 8 | lixourion
# Processing Record 27 of Set 8 | sawtell
# Processing Record 28 of Set 8 | inuvik
# Processing Record 29 of Set 8 | isangel
# Processing Record 30 of Set 8 | coquimbo
# Processing Record 31 of Set 8 | sembe
# Processing Record 32 of Set 8 | qui nhon
# Processing Record 33 of Set 8 | bolivar
# Processing Record 34 of Set 8 | newport
# Processing Record 35 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 36 of Set 8 | veraval
# Processing Record 37 of Set 8 | roxas
# Processing Record 38 of Set 8 | nemuro
# Processing Record 39 of Set 8 | klaksvik
# Processing Record 40 of Set 8 | muros
# Processing Record 41 of Set 8 | elizabeth city
# Processing Record 42 of Set 8 | kawalu
# Processing Record 43 of Set 8 | vetluga
# Processing Record 44 of Set 8 | moree
# Processing Record 45 of Set 8 | alyangula
# Processing Record 46 of Set 8 | cabo san lucas
# Processing Record 47 of Set 8 | port blair
# Processing Record 48 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 49 of Set 8 | pareora
# Processing Record 50 of Set 8 | sarakhs
# Processing Record 1 of Set 9 | sabang
# Processing Record 2 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 9 | tilichiki
# Processing Record 4 of Set 9 | ust-maya
# Processing Record 5 of Set 9 | taoudenni
# Processing Record 6 of Set 9 | monrovia
# Processing Record 7 of Set 9 | flin flon
# Processing Record 8 of Set 9 | ola
# Processing Record 9 of Set 9 | coxim
# Processing Record 10 of Set 9 | shingu
# Processing Record 11 of Set 9 | hasaki
# Processing Record 12 of Set 9 | teguise
# Processing Record 13 of Set 9 | longyearbyen
# Processing Record 14 of Set 9 | chickasha
# Processing Record 15 of Set 9 | yinchuan
# Processing Record 16 of Set 9 | khasan
# Processing Record 17 of Set 9 | merauke
# Processing Record 18 of Set 9 | puerto escondido
# Processing Record 19 of Set 9 | tocopilla
# Processing Record 20 of Set 9 | umm lajj
# Processing Record 21 of Set 9 | nurobod
# Processing Record 22 of Set 9 | kavaratti
# Processing Record 23 of Set 9 | rawson
# Processing Record 24 of Set 9 | abu samrah
# Processing Record 25 of Set 9 | harer
# Processing Record 26 of Set 9 | beloha
# Processing Record 27 of Set 9 | huilong
# Processing Record 28 of Set 9 | byron bay
# Processing Record 29 of Set 9 | hurghada
# Processing Record 30 of Set 9 | bowen
# Processing Record 31 of Set 9 | ahipara
# Processing Record 32 of Set 9 | linqiong
# Processing Record 33 of Set 9 | oktyabrskiy
# Processing Record 34 of Set 9 | conde
# Processing Record 35 of Set 9 | comodoro rivadavia
# Processing Record 36 of Set 9 | arteaga
# Processing Record 37 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 38 of Set 9 | fairbanks
# Processing Record 39 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 9 | simao
# Processing Record 41 of Set 9 | santa fe
# Processing Record 42 of Set 9 | broome
# Processing Record 43 of Set 9 | malumfashi
# Processing Record 44 of Set 9 | nicholasville
# Processing Record 45 of Set 9 | topolobampo
# Processing Record 46 of Set 9 | aguimes
# Processing Record 47 of Set 9 | belle glade
# Processing Record 48 of Set 9 | matagami
# Processing Record 49 of Set 9 | lorengau
# Processing Record 50 of Set 9 | nacala
# Processing Record 1 of Set 10 | lake city
# Processing Record 2 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 3 of Set 10 | waddan
# Processing Record 4 of Set 10 | khani
# Processing Record 5 of Set 10 | te anau
# Processing Record 6 of Set 10 | ketrzyn
# Processing Record 7 of Set 10 | camargo
# Processing Record 8 of Set 10 | champerico
# Processing Record 9 of Set 10 | lichinga
# Processing Record 10 of Set 10 | paso de los toros
# Processing Record 11 of Set 10 | mus
# Processing Record 12 of Set 10 | robertsport
# Processing Record 13 of Set 10 | bilma
# Processing Record 14 of Set 10 | fleury-les-aubrais
# Processing Record 15 of Set 10 | thessalon
# Processing Record 16 of Set 10 | juneau
# Processing Record 17 of Set 10 | kahului
# Processing Record 18 of Set 10 | concordia
# Processing Record 19 of Set 10 | coahuayana
# Processing Record 20 of Set 10 | visby
# Processing Record 21 of Set 10 | letlhakane
# Processing Record 22 of Set 10 | mayo
# Processing Record 23 of Set 10 | naryan-mar
# Processing Record 24 of Set 10 | aksaray
# Processing Record 25 of Set 10 | ketchikan
# Processing Record 26 of Set 10 | villaviciosa
# Processing Record 27 of Set 10 | anadyr
# Processing Record 28 of Set 10 | basay
# Processing Record 29 of Set 10 | muzquiz
# City not found. Skipping...
# Processing Record 30 of Set 10 | lincoln
# Processing Record 31 of Set 10 | san patricio
# Processing Record 32 of Set 10 | raudeberg
# Processing Record 33 of Set 10 | natal
# Processing Record 34 of Set 10 | arlit
# Processing Record 35 of Set 10 | faanui
# Processing Record 36 of Set 10 | hargeysa
# Processing Record 37 of Set 10 | desaguadero
# Processing Record 38 of Set 10 | winneba
# Processing Record 39 of Set 10 | san francisco
# Processing Record 40 of Set 10 | cheremukhovo
# Processing Record 41 of Set 10 | gilbues
# Processing Record 42 of Set 10 | toora-khem
# Processing Record 43 of Set 10 | norilsk
# Processing Record 44 of Set 10 | kloulklubed
# Processing Record 45 of Set 10 | mgachi
# Processing Record 46 of Set 10 | mecca
# Processing Record 47 of Set 10 | oboyan
# Processing Record 48 of Set 10 | kysyl-syr
# Processing Record 49 of Set 10 | conakry
# Processing Record 50 of Set 10 | nacimiento
# Processing Record 1 of Set 11 | ilhabela
# Processing Record 2 of Set 11 | denpasar
# Processing Record 3 of Set 11 | sinnamary
# Processing Record 4 of Set 11 | williams lake
# Processing Record 5 of Set 11 | luangwa
# Processing Record 6 of Set 11 | westport
# Processing Record 7 of Set 11 | patacamaya
# Processing Record 8 of Set 11 | arrecife
# Processing Record 9 of Set 11 | virginia beach
# Processing Record 10 of Set 11 | yumen
# Processing Record 11 of Set 11 | fasa
# Processing Record 12 of Set 11 | leshukonskoye
# Processing Record 13 of Set 11 | taihe
# Processing Record 14 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 11 | marsa matruh
# Processing Record 16 of Set 11 | maxixe
# Processing Record 17 of Set 11 | barcelos
# Processing Record 18 of Set 11 | aktau
# Processing Record 19 of Set 11 | sistranda
# Processing Record 20 of Set 11 | hauterive
# Processing Record 21 of Set 11 | kosa
# Processing Record 22 of Set 11 | port lincoln
# Processing Record 23 of Set 11 | faya
# Processing Record 24 of Set 11 | tubruq
# City not found. Skipping...
# Processing Record 25 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 11 | bryanka
# Processing Record 27 of Set 11 | bacuit
# City not found. Skipping...
# Processing Record 28 of Set 11 | salinas
# Processing Record 29 of Set 11 | santo antonio do monte
# Processing Record 30 of Set 11 | rotifunk
# Processing Record 31 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 32 of Set 11 | mandurah
# Processing Record 33 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 11 | alta
# Processing Record 35 of Set 11 | tarare
# Processing Record 36 of Set 11 | roma
# Processing Record 37 of Set 11 | sasaram
# Processing Record 38 of Set 11 | trairi
# Processing Record 39 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 11 | hofn
# Processing Record 41 of Set 11 | crab hill
# City not found. Skipping...
# Processing Record 42 of Set 11 | seryshevo
# Processing Record 43 of Set 11 | the pas
# Processing Record 44 of Set 11 | phalodi
# Processing Record 45 of Set 11 | san andres
# Processing Record 46 of Set 11 | todos santos
# Processing Record 47 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 48 of Set 11 | guayaramerin
# Processing Record 49 of Set 11 | novikovo
# Processing Record 50 of Set 11 | balkanabat
# Processing Record 1 of Set 12 | oistins
# Processing Record 2 of Set 12 | paamiut
# Processing Record 3 of Set 12 | pinsk
# Processing Record 4 of Set 12 | vila
# Processing Record 5 of Set 12 | dingle
# Processing Record 6 of Set 12 | cap malheureux
# Processing Record 7 of Set 12 | phuthaditjhaba
# Processing Record 8 of Set 12 | ushtobe
# Processing Record 9 of Set 12 | englehart
# Processing Record 10 of Set 12 | camana
# Processing Record 11 of Set 12 | kidal
# Processing Record 12 of Set 12 | kankon
# Processing Record 13 of Set 12 | labuhan
# Processing Record 14 of Set 12 | matay
# Processing Record 15 of Set 12 | naze
# Processing Record 16 of Set 12 | gasa
# Processing Record 17 of Set 12 | gorontalo
# Processing Record 18 of Set 12 | owando
# Processing Record 19 of Set 12 | shitanjing
# Processing Record 20 of Set 12 | havre
# Processing Record 21 of Set 12 | kon tum
# Processing Record 22 of Set 12 | rindal
# Processing Record 23 of Set 12 | auki
# Processing Record 24 of Set 12 | chicama
# Processing Record 25 of Set 12 | kenora
# Processing Record 26 of Set 12 | karratha
# Processing Record 27 of Set 12 | anloga
# Processing Record 28 of Set 12 | pafos
# Processing Record 29 of Set 12 | marawi
# Processing Record 30 of Set 12 | pavia
# Processing Record 31 of Set 12 | hokitika
# Processing Record 32 of Set 12 | benjamin constant
# Processing Record 33 of Set 12 | bossangoa
# Processing Record 34 of Set 12 | sitio novo do tocantins
# Processing Record 35 of Set 12 | itamaraju
# Processing Record 36 of Set 12 | tripoli
# Processing Record 37 of Set 12 | sibay
# Processing Record 38 of Set 12 | dabat
# Processing Record 39 of Set 12 | oranjestad
# Processing Record 40 of Set 12 | guiratinga
# Processing Record 41 of Set 12 | nantucket
# Processing Record 42 of Set 12 | slave lake
# Processing Record 43 of Set 12 | srednekolymsk
# Processing Record 44 of Set 12 | maniitsoq
# Processing Record 45 of Set 12 | jiquinlaca
# Processing Record 46 of Set 12 | mineiros
# Processing Record 47 of Set 12 | amuntai
# Processing Record 48 of Set 12 | toowoomba
# Processing Record 49 of Set 12 | mayumba
# Processing Record 50 of Set 12 | jalu
# Processing Record 1 of Set 13 | laramie
# Processing Record 2 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 3 of Set 13 | dimitrovgrad
# Processing Record 4 of Set 13 | mende
# Processing Record 5 of Set 13 | tateyama
# Processing Record 6 of Set 13 | el transito
# Processing Record 7 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 8 of Set 13 | ishim
# Processing Record 9 of Set 13 | issa
# Processing Record 10 of Set 13 | dillingen
# Processing Record 11 of Set 13 | port-de-bouc
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Convert the array of dictionaries to a pandas DataFrame.

city_data_df = pd.DataFrame(city_data)

city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Katsuura  35.1333  140.3000     79.90        90          73
# 1   San Quintin  30.4833 -115.9500     72.09        65           0
# 2      Akcaabat  41.0212   39.5715     76.87        69           0
# 3  Constitucion -35.3333  -72.4167     50.05        61           3
# 4       Salalah  17.0151   54.0924     80.69        89          75
#
#    Wind Speed Country                 Date
# 0       18.28      JP  2022-09-18 22:18:36
# 1       15.77      MX  2022-09-18 22:18:36
# 2        6.91      TR  2022-09-18 22:18:37
# 3       14.58      CL  2022-09-18 22:18:37
# 4        5.75      OM  2022-09-18 22:18:37

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0       Katsuura      JP  2022-09-18 22:18:36  35.1333  140.3000     79.90
# 1    San Quintin      MX  2022-09-18 22:18:36  30.4833 -115.9500     72.09
# 2       Akcaabat      TR  2022-09-18 22:18:37  41.0212   39.5715     76.87
# 3   Constitucion      CL  2022-09-18 22:18:37 -35.3333  -72.4167     50.05
# 4        Salalah      OM  2022-09-18 22:18:37  17.0151   54.0924     80.69
# 5    Provideniya      RU  2022-09-18 22:18:38  64.3833 -173.3000     41.36
# 6    Tuktoyaktuk      CA  2022-09-18 22:18:38  69.4541 -133.0374     51.80
# 7        Erenhot      CN  2022-09-18 22:18:38  43.6475  111.9767     50.85
# 8  Black Diamond      US  2022-09-18 22:16:17  47.3087 -122.0032     75.81
# 9          Alofi      NU  2022-09-18 22:18:39 -19.0595 -169.9187     80.49
#
#    Humidity  Cloudiness  Wind Speed
# 0        90          73       18.28
# 1        65           0       15.77
# 2        69           0        6.91
# 3        61           3       14.58
# 4        89          75        5.75
# 5       100         100        7.00
# 6        71          75       12.66
# 7        30         100        8.57
# 8        45           7        3.00
# 9        74           6       14.97

# %%
#Create the output file

output_data_file = "weather_data/cities.csv"

#Export the City_Data into a CSV.

city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
#Import the time module

import time

#Build the scatter plot for the latitude vs. max temperature

plt.scatter(lats,
           max_temps,
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")

#Incorporate the other graph properties.

plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

#Save the figure

plt.savefig("weather_data/Fig1.png")

#Show Plot. 

plt.show()

# %%
plt.scatter(lats,
           humidity,
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")

#Incorporate the other graph properties.

plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

#Save the figure

plt.savefig("weather_data/Fig2.png")

#Show Plot. 

plt.show()

# %%
plt.scatter(lats,
           cloudiness,
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")

#Incorporate the other graph properties.

plt.title(f"City Latitude vs. Cloudiness "+ time.strftime("%x"))
plt.ylabel("Cloudiness(%)")
plt.xlabel("Latitude")
plt.grid(True)

#Save the figure

plt.savefig("weather_data/Fig3.png")

#Show Plot. 

plt.show()

# %%
plt.scatter(lats,
           wind_speed,
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")

#Incorporate the other graph properties.

plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

#Save the figure

plt.savefig("weather_data/Fig4.png")

#Show Plot. 

plt.show()

# %%
#Import linregress

from scipy.stats import linregress

#Create a function to perform linear regression on the weather data
#and plot a regression line and the equation with the data. 

def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    #Run reression on hemisphere weather data. 
    
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    #Calculate the regression line "y values" from the slope and intercept.
    
    regress_values = x_values * slope +intercept
    
    #Get the equatio of the line.
    
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    #Create a scatter plot and plot the regression line. 
    
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values,"r")
    
    #Annotate the text for the line equation. 
    
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City                  New Norfolk
# Country                        AU
# Date          2022-09-18 22:18:41
# Lat                      -42.7826
# Lng                      147.0587
# Max Temp                    52.92
# Humidity                       69
# Cloudiness                    100
# Wind Speed                    4.0
# Name: 13, dtype: object

# %%
city_data_df["Lat"] >= 0
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 563     True
# 564     True
# 565     True
# 566     True
# 567     True
# Name: Lat, Length: 568, dtype: bool

# %%
city_data_df.loc[(city_data_df["Lat"] >=0)].head()
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0     Katsuura      JP  2022-09-18 22:18:36  35.1333  140.3000     79.90
# 1  San Quintin      MX  2022-09-18 22:18:36  30.4833 -115.9500     72.09
# 2     Akcaabat      TR  2022-09-18 22:18:37  41.0212   39.5715     76.87
# 4      Salalah      OM  2022-09-18 22:18:37  17.0151   54.0924     80.69
# 5  Provideniya      RU  2022-09-18 22:18:38  64.3833 -173.3000     41.36
#
#    Humidity  Cloudiness  Wind Speed
# 0        90          73       18.28
# 1        65           0       15.77
# 2        69           0        6.91
# 4        89          75        5.75
# 5       100         100        7.00

# %%
#Create Northern and Southern Hemisphere DataFrames.

northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >=0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] <=0)]

# %%
#Linear regression on the Northern Hemisphere.
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

#Call the function. 

plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere for Maximum Temperature', 'Max Temp', (0,30))

print(linregress(x_values,y_values))
# Out:
# LinregressResult(slope=-0.6434199006232038, intercept=90.35658857603399, rvalue=-0.7732466986853864, pvalue=5.840516722376757e-80, stderr=0.026582124834267043, intercept_stderr=1.1558389200612615)

# %%
#Linear regression on the Southern Hemisphere.
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

#Call the function. 

plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere for Maximum Temperature', 'Max Temp', (-55,90))

print(linregress(x_values,y_values))
# Out:
# LinregressResult(slope=0.7268689270705034, intercept=82.34259543082202, rvalue=0.8001755632836784, pvalue=1.3752396614362305e-39, stderr=0.04178573910675309, intercept_stderr=1.0745730993537839)

# %%
#Linear regression on the Northern Hemisphere (% Humidity.
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

#Call the function. 

plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere for % Humidity', '% Humidity', (47,20))

print(linregress(x_values,y_values))
# Out:
# LinregressResult(slope=-0.0007965784059444579, intercept=72.4602102101419, rvalue=-0.0007438219856915668, pvalue=0.9882275753916683, stderr=0.05395246443484665, intercept_stderr=2.3459508453826827)

# %%
#Linear regression on the Southern Hemisphere (% Humidity).
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

#Call the function. 

plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere for % Humidity', '% Humidity', (-55,30))

print(linregress(x_values,y_values))
# Out:
# LinregressResult(slope=0.019840873774352567, intercept=71.66355674492782, rvalue=0.014176306009742514, pvalue=0.8535631193329085, stderr=0.10733209594743315, intercept_stderr=2.7601805177530343)

# %%
#Linear regression on the Northern Hemisphere (Cloudiness).
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

#Call the function. 

plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere for Cloudiness', '% Cloudiness', (45,40))

print(linregress(x_values,y_values))
# Out:
# LinregressResult(slope=0.1404935363895923, intercept=53.7768782300198, rvalue=0.06925482242159386, pvalue=0.16899231601174877, stderr=0.10195633593651372, intercept_stderr=4.433246098910384)

# %%
#Linear regression on the Southern Hemisphere (Cloudiness).
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

#Call the function. 

plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere for Cloudiness', '% Cloudiness', (-55,15))

print(linregress(x_values,y_values))
# Out:
# LinregressResult(slope=-0.19696664768951563, intercept=48.401995259521826, rvalue=-0.0686298155686786, pvalue=0.37102036110277437, stderr=0.21959892509431383, intercept_stderr=5.647263937356556)

# %%
#Linear regression on the Northern Hemisphere (Wind_Speed).
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

#Call the function. 

plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere for Wind Speed', 'Windspeed', (0,30))

print(linregress(x_values,y_values))
# Out:
# LinregressResult(slope=0.04933370174050233, intercept=7.108008433482308, rvalue=0.1671965168007114, pvalue=0.0008372028536356616, stderr=0.01465587071540334, intercept_stderr=0.6372637960985015)

# %%
#Linear regression on the Southern Hemisphere (Wind_Speed).
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

#Call the function. 

plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere for Wind Speed', 'Windspeed', (-55,21))

print(linregress(x_values,y_values))
# Out:
# LinregressResult(slope=-0.032295783332987285, intercept=7.344854830416911, rvalue=-0.08483025102725666, pvalue=0.2685441299164102, stderr=0.029093926114102456, intercept_stderr=0.748187085477411)
